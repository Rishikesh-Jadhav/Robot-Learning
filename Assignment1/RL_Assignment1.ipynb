# %% [markdown]
# # **Python Tutorial and Homework 2**

# %% [markdown]
# This Colab Notebook contains 2 sections. The first section is a Python Tutorial intended to make you familiar with Numpy and Colab functionalities. **This section will not be graded**.
#
# The second section is a coding assignment (Homework 2). **This section will be graded**

# %% [markdown]
# # 1.0 **Python Tutorial**
#
# This assignment section won't be graded but is intended as a tutorial to refresh the basics of python and its dependencies. It also allows one to get familiarized with Google Colab.

# %% [markdown]
# ## 1.0.0 Array manipulation using numpy

# %% [markdown]
# #### Q1 - Matrix multiplication

# %%
import numpy as np

### Create two numpy arrays with the dimensions 3x2 and 2x3 respectively using  np.arange().
### The elements of the vector are
### Vector 1 elements = [ 2,  4,  6,  8, 10, 12];
### Vector 2 elements = [ 7, 10, 13, 16, 19, 22]

### Starting at 2, stepping by 2
vector1 =np.arange(2, 13, 2).reshape(3, 2)
### Starting at 7, stepping by 3
vector2 =np.arange(7, 23, 3).reshape(2, 3)

### Print vec
# print(vector1, vector2)

### Take product of the two matricies (Matrix product)
prod = np.dot(vector1, vector2)

### Print
print(prod)
# Out:
# [[ 78  96 114]
#  [170 212 254]
#  [262 328 394]]

# %% [markdown]
# #### Q2 - Diagonals

# %%
### Create two numpy arrays with the dimensions 10x10 using the function np.arange().
### Starting at 2, stepping by 3
vector1 =
### Starting at 35, stepping by 9
vector2 =

### Print vec
# print(vector1,vector2)

### Obtain the diagonal matrix of each vector1 such that the start of the diagonal is from (3,0) and the end is (9,6)
### Reshape the the matrix such that it form a diagonal maritix of shape(7,7)
vector1_offset_diagonal =


### Obtain a 7x7 matrix from the vector 2
### starting from (left top element) = (0,3)
### ending at (right bottom element) = (6,9)
vector2_offset_diagonal =

### Print diagonal matrix
# print(vector1_offset_diagonal, vector2_offset_diagonal)


### Take product of the two diagonal matricies (Matrix product)
prod =

### Print
print(prod)

# %% [markdown]
# #### Q3 - Sin wave

# %% [markdown]
# Sample outputs,
# ![download.png](data:image/png;base64,...) ![download (1).png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
### Create a time matrix that evenly samples a sine wave at a frequency of 1Hz
### Starting at time step T = 0
### End at time step T = 500
time = np.arange(0, 501, 1)

### Given wavelength of
wavelength = 500

### Construct a sin wave using the formula sin(2*pi*(time/wavelength))
y = np.sin(2 * np.pi * (time / wavelength))

#### Plot the wave
plt.plot(time, y)
plt.show()

# %%
#### Given a 2D mesh grid
X, Y = np.meshgrid(time, time)
#### wavelength and angle of rotation(phi) of the sin wave in 2d. Imagine a 2D sine wave is being rotating about the Z axes
wavelength = 200
phi = np.pi / 3

#### Calculate the sin wave in 2d space using the formula sin(2*pi*(x'/wavelength)) where x'=Xcos(phi) + Ysin(phi)
grating = np.sin(2 * np.pi * ((X * np.cos(phi) + Y * np.sin(phi)) / wavelength))

#### Plot the wave
#### Intuition, think of the white area as hills and the black areas as valleys
plt.set_cmap("gray")
plt.imshow(grating)
plt.show()

# %% [markdown]
# #### Q4 Car Brands

# %%
cars = ['Civic', 'Insight', 'Fit', 'Accord', 'Ridgeline', 'Avancier','Pilot', 'Legend', 'Beat', 'FR-V', 'HR-V', 'Shuttle']

#### Create a 3D array of cars of shape 2,3,2
cars_3d = np.array(cars).reshape(2,3,2)

#### Extract the top layer of the matrix. Top layer of a matrix A of shape(2,3,2) will have the following structue A_top = [[A[0,0,0], A[0,0,1]],[A[0,1,0],A[0,1,1]],[A[0,2,0],A[0,2,1]]]
#### HINT - Array slicing or splitting
cars_top_layer = cars_3d[0]

#### Similarly extract the bottom layer
#### HINT - Array slicing or splitting
cars_bottom_layer =cars_3d[1]

#### Print layers
print("\nTop Layer \n ",cars_top_layer,"\nBottom Layer\n", cars_bottom_layer)

#### Flatten the top layer
cars_top_flat = cars_top_layer.flatten()
#### Flatten the bottom layer
cars_bottom_flat = cars_bottom_layer.flatten()

#### Print layers
print("\nTop Flattened : ",cars_top_flat,"\nBottom Flattened : ",cars_bottom_flat)


new_car_list = np.empty((cars_top_layer.size + cars_bottom_layer.size,), dtype=object)
#### Interweave the to flattened lists and insert into new_car_list such that new_car_list=['Civic' 'Pilot' 'Fit' 'Beat' 'Ridgeline' 'HR-V' 'Insight' 'Legend' 'Accord' 'FR-V' 'Avancier' 'Shuttle']
#### Using only array slicing
new_car_list[0::2] =cars_top_flat
new_car_list[1::2] =cars_bottom_flat


#### Concatenate and flatten the top and bottom layer such that the final list is of the form cat_flat = ['Civic' 'Insight' 'Pilot' 'Legend' 'Fit' 'Accord' 'Beat' 'FR-V' 'Ridgeline' 'Avancier' 'HR-V' 'Shuttle']
cat_flat =np.concatenate((cars_top_layer, cars_bottom_layer)).flatten()

#### Print layers
print("\n\nInterwoven - ", new_car_list,"\nConcatenate and flatten - ", cat_flat)
# Out:
# Top Layer
#   [['Civic' 'Insight']
#  ['Fit' 'Accord']
#  ['Ridgeline' 'Avancier']]
# Bottom Layer
#  [['Pilot' 'Legend']
#  ['Beat' 'FR-V']
#  ['HR-V' 'Shuttle']]
#
# Top Flattened :  ['Civic' 'Insight' 'Fit' 'Accord' 'Ridgeline' 'Avancier']
# Bottom Flattened :  ['Pilot' 'Legend' 'Beat' 'FR-V' 'HR-V' 'Shuttle']
#
#
# Interwoven -  ['Civic' 'Pilot' 'Insight' 'Legend' 'Fit' 'Beat' 'Accord' 'FR-V'
#  'Ridgeline' 'HR-V' 'Avancier' 'Shuttle']
# Concatenate and flatten -  ['Civic' 'Insight' 'Fit' 'Accord' 'Ridgeline' 'Avancier' 'Pilot' 'Legend'
#  'Beat' 'FR-V' 'HR-V' 'Shuttle']

# %% [markdown]
# ## 1.0.1 Basics tensorflow

# %% [markdown]
# #### Helper functions

# %%
import tensorflow as tf
from keras.utils import to_categorical

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# #### Q1 MNIST Classifier

# %%
## Import the MNIST dataset from keras
mnist = tf.keras.datasets.mnist
### Load the data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

### Normalize the 8bit images with values in the range [0,255]
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
## Create a model with the following architecture Flatten -> Dense(128, relu) -> Dense(64,relu) -> outpuLayer(size=10)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten layer
    Dense(128, activation='relu'),  # Dense layer with 128 units and ReLU activation
    Dense(64, activation='relu'),   # Dense layer with 64 units and ReLU activation
    Dense(10, activation='softmax') # Output layer with 10 units and softmax activation
])


### Complie the model with the adam optimizer and crossentropy loss
### HINT - No One hot encoding
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
### Train the model on the train data for 5 epochs
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2417 - accuracy: 0.9285
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0997 - accuracy: 0.9698
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0689 - accuracy: 0.9777
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0538 - accuracy: 0.9829
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0412 - accuracy: 0.9861

# %%
### Check the accuracy of the trained model
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.0738 - accuracy: 0.9796 - 726ms/epoch - 2ms/step
#
# Test accuracy: 0.9796000123023987

# %%
### Convert the above model to a probabilistic model with a softmax as the output layer
probability_model = tf.keras.Sequential([
    model,
    tf.keras.layers.Softmax()
])


### Run the test data through the new model and get predictions
predictions = probability_model.predict(x_test)

### Plot a test output
i = 42 ### <---- Change this to some random number to see different predictions
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  y_test)
plt.show()
### Blue bars mean correct guess red bar means wrong guess!!
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %% [markdown]
# ## 1.0.2 Basic Pytorch Tutorial

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# Set the random seed for reproducibility
torch.manual_seed(42)

# Define a simple feedforward neural network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 128)  # 28x28 input size (MNIST images are 28x28 pixels)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)   # 10 output classes (digits 0-9)

    def forward(self, x):
        x = x.view(-1, 784)  # Flatten the input image
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Load the MNIST dataset and apply transformations
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# Initialize the neural network and optimizer
net = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f'Epoch {epoch+1}, Loss: {running_loss / len(trainloader)}')

print('Finished Training')

# Evaluate the model on the test set
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy on test set: {100 * correct / total}%')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 42271113.33it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 23812796.11it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 5840463.49it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 7290673.08it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Epoch 1, Loss: 0.7497771851766084
# Epoch 2, Loss: 0.3669367114395729
# Epoch 3, Loss: 0.3210167052077332
# Epoch 4, Loss: 0.29383885016096933
# Epoch 5, Loss: 0.2732162083000707
# Epoch 6, Loss: 0.2538067396285374
# Epoch 7, Loss: 0.23667215858139337
# Epoch 8, Loss: 0.22128436360945072
# Epoch 9, Loss: 0.20731170845629054
# Epoch 10, Loss: 0.1948725388272167
# Finished Training
# Accuracy on test set: 94.49%

# %% [markdown]
# # 2.0 **Homework 2**
# 90 points
#
# *Note : This section will be graded and must be attemped using Pytorch only*

# %% [markdown]
# ## Graded Section : Deep Learning Approach

# %% [markdown]
# Time-Series Prediction
# Time series and sequence prediction could be a really amazing to predict/estimate a robot's trajectory which requires temporal data at hand. In this assignemnt we will see how this could be done using Deep Learning.
#
# Given a dataset [link](https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv) for airline passengers prediction problem. Predict the number of international airline passengers in units of 1,000 given a year and a month.
# Here is how the data looks like.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
file_name = '/content/drive/MyDrive/airline-passengers.csv' # dataset path
# Reading data using pandas or csv
df = pd.read_csv(file_name)

# %%
# plotting the dataset
timeseries = df[["Passengers"]].values.astype('float32')
# plotting the dataset
plt.plot(timeseries)
plt.show()

# %% [markdown]
# 1. Write the dataloader code to pre-process the data for pytorch tensors using any library of your choice. Here is a good resource for the dataloader [Video link](https://www.youtube.com/watch?v=PXOzkkB5eH0)

# %%
# Write your code here for the dataloader in Pytorch
import torch
from torch.utils.data import TensorDataset, DataLoader
import pandas as pd

# Converting pandas DataFrame to a PyTorch tensor
timeseries_tensor = torch.tensor(df["Passengers"].values, dtype=torch.float32)
window_size = 12  # window size of 12 for monthly data

# Creating sequences of data with above window size
sequences = []
for i in range(len(timeseries_tensor) - window_size):
    sequence = timeseries_tensor[i:i+window_size]
    sequences.append(sequence)

# Converting the list of sequences into a PyTorch tensor
input_data = torch.stack(sequences)

# Defining the target data by shifting input data by one time step
target_data = timeseries_tensor[window_size:]

# Batch size for training
batch_size = 32

# PyTorch DataLoader for handling the data in batches
dataset = TensorDataset(input_data, target_data)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# 2. Create the model in pytorch here uinsg 1. Long-Short Term Memory (LSTM) and 2. Recurrent Neural Network (RNN). Here is a good resource for Custom model generation.
#
#   Train using the two models. Here is the resource for the same [Video link](https://www.youtube.com/watch?v=VVDHU_TWwUg)

# %%
# write your code here for the custom model creating for both the methods

# LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        output = self.fc(lstm_out[:, -1, :])
        return output

# RNN model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        rnn_out, _ = self.rnn(x)
        output = self.fc(rnn_out[:, -1, :])
        return output

# model parameters
input_size = 1  # univariate time series
hidden_size = 64
output_size = 1

# Instantiating LSTM and RNN models
lstm_net = LSTMModel(input_size, hidden_size, output_size)
rnn_net = RNNModel(input_size, hidden_size, output_size)

# Loss function and optimizer
criterion = nn.MSELoss()
lstm_optimizer = torch.optim.Adam(lstm_net.parameters(), lr=0.001)
rnn_optimizer = torch.optim.Adam(rnn_net.parameters(), lr=0.001)

num_epochs = 10

# Training loop for LSTM model
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(dataloader):
        lstm_optimizer.zero_grad()
        lstm_output = lstm_net(inputs.unsqueeze(-1))
        loss = criterion(lstm_output, labels.unsqueeze(-1))
        loss.backward()
        lstm_optimizer.step()

        running_loss += loss.item()

    print(f'Epoch {epoch+1}, LSTM Loss: {running_loss / len(dataloader)}')

print('Finished Training LSTM')

# Training loop for RNN model
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(dataloader):
        rnn_optimizer.zero_grad()
        rnn_output = rnn_net(inputs.unsqueeze(-1))
        loss = criterion(rnn_output, labels.unsqueeze(-1))
        loss.backward()
        rnn_optimizer.step()

        running_loss += loss.item()

    print(f'Epoch {epoch+1}, RNN Loss: {running_loss / len(dataloader)}')

print('Finished Training RNN')
# Out:
# Epoch 1, LSTM Loss: 101643.3703125
# Epoch 2, LSTM Loss: 90251.07734375
# Epoch 3, LSTM Loss: 100185.4203125
# Epoch 4, LSTM Loss: 99207.00625
# Epoch 5, LSTM Loss: 90853.978125
# Epoch 6, LSTM Loss: 97798.81875
# Epoch 7, LSTM Loss: 100676.95
# Epoch 8, LSTM Loss: 106289.4875
# Epoch 9, LSTM Loss: 92189.2296875
# Epoch 10, LSTM Loss: 92539.5140625
# Finished Training LSTM
# Epoch 1, RNN Loss: 94801.46875
# Epoch 2, RNN Loss: 90760.75625
# Epoch 3, RNN Loss: 103809.19375
# Epoch 4, RNN Loss: 92232.63828125
# Epoch 5, RNN Loss: 101293.6265625
# Epoch 6, RNN Loss: 96574.8796875
# Epoch 7, RNN Loss: 94459.609375
# Epoch 8, RNN Loss: 97684.30625
# Epoch 9, RNN Loss: 95516.5203125
# Epoch 10, RNN Loss: 91349.70625
# Finished Training RNN

# %% [markdown]
# 3. Evaluate and Compare the result using proper metric. Justify the metrics used.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import numpy as np

# Evaluating LSTM model
lstm_net.eval()
lstm_predictions = []
lstm_targets = []

with torch.no_grad():
    for inputs, labels in dataloader:
        lstm_output = lstm_net(inputs.unsqueeze(-1))
        lstm_predictions.extend(lstm_output.squeeze().tolist())
        lstm_targets.extend(labels.tolist())

lstm_predictions = np.array(lstm_predictions)
lstm_targets = np.array(lstm_targets)

lstm_mse = mean_squared_error(lstm_targets, lstm_predictions)
lstm_mae = mean_absolute_error(lstm_targets, lstm_predictions)
lstm_rmse = np.sqrt(lstm_mse)


print("Evaluation results for LSTM model:")
print(f"MSE: {lstm_mse}")
print(f"MAE: {lstm_mae}")
print(f"RMSE: {lstm_rmse}")


# Evaluating RNN model
rnn_net.eval()
rnn_predictions = []
rnn_targets = []

with torch.no_grad():
    for inputs, labels in dataloader:
        rnn_output = rnn_net(inputs.unsqueeze(-1))
        rnn_predictions.extend(rnn_output.squeeze().tolist())
        rnn_targets.extend(labels.tolist())

rnn_predictions = np.array(rnn_predictions)
rnn_targets = np.array(rnn_targets)

rnn_mse = mean_squared_error(rnn_targets, rnn_predictions)
rnn_mae = mean_absolute_error(rnn_targets, rnn_predictions)
rnn_rmse = np.sqrt(rnn_mse)


print("\nEvaluation results for RNN model:")
print(f"MSE: {rnn_mse}")
print(f"MAE: {rnn_mae}")
print(f"RMSE: {rnn_rmse}")
# Out:
# Evaluation results for LSTM model:
# MSE: 98733.69096345609
# MAE: 292.37033622373235
# RMSE: 314.21917663226105
#
# Evaluation results for RNN model:
# MSE: 97086.76356156122
# MAE: 289.5653667413827
# RMSE: 311.58748941759717

# %% [markdown]
# Mean Squared Error (MSE):
#
# Justification: In the context of time series forecasting, MSE provides a measure of the overall accuracy of the models in predicting future values over the entire dataset.
#
# Mean Absolute Error (MAE):
#
# Justification: It offers insight into the magnitude of errors in the predictions, making it interpretable and suitable for comparing the models' precision in forecasting.
#
# Root Mean Squared Error (RMSE):
#
# Justification: RMSE helps in understanding the typical magnitude of errors in the predictions and is commonly used in time series forecasting tasks.

# %% [markdown]
# [Bonus 5 points] Suggest some things that could be done to improve the results.
#
# My Answer :
# Hyperparameter Tuning: We can experiment with different hyperparameters such as learning rate, batch size, number of epochs, and hidden layer sizes. We can also perform systematic hyperparameter tuning using techniques like grid search or random search to find the optimal combination of hyperparameters.
#
# Feature Engineering: We can explore additional features or transformations of existing features that may provide more useful information to the models. For example, we can include lagged values of the time series, trend information, seasonal patterns, or other relevant variables.
#
# Regularization: We can apply regularization techniques such as dropout or L2 regularization to prevent overfitting. Experimentation with different dropout rates or regularization strengths will be useful to prevent overfitting and preserving model performance.
#
# Model Architecture: We can try alternative model architectures or variations of LSTM and RNN models. For example, you can try Bidirectional LSTMs, GRUs (Gated Recurrent Units), or attention mechanisms to capture temporal dependencies more effectively.
#
# Transfer Learning: We can try out transfer learning techniques by pre-training the models on related tasks or datasets before fine-tuning them on the target time series data. Transfer learning can help leverage knowledge from existing domains to improve performance on the target task.

# %% [markdown]
# [Bonus 5 points] Suggest where this could be used in Robotics other than the example given in the beginning.
#
# My Answer: Sensor Data Processing: Robotics systems often rely on sensor data for perception and decision-making. LSTM and RNN models can be used to process and interpret sensor data in real-time, helping robots to make predictions about environment, such as detecting anomalies or predicting object trajectories.
#
# Fault Detection and Diagnosis: By analyzing time series data from sensors and actuators, these models can identify abnormal patterns or deviations from expected behavior, enabling proactive maintenance, fault isolation, and system recovery in autonomous robots or industrial automation settings.
